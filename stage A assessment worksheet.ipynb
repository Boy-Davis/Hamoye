# %% [markdown]
# ### Stage A Tag Along Code

# %% [markdown]
# #### This sheet contains all the codes used in proffering solutions to the quiz of the stage A course

# %%
# Importing the needed libraries
import numpy as np
import pandas as pd

# %%
# reading the food dataset into the dataframe
food_df = pd.read_csv('food_balance_sheet.csv', encoding='latin-1')
food_df
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %% [markdown]
# #### Question 1: Select columns ‘Y2017’ and ‘Area’, Perform a groupby operation on ‘Area’. Which of these Areas had the 7th lowest sum in 2017?

# %%
food_by_area = food_df.loc[:, ['Y2017', 'Area']]

# %%
food_by_area.groupby('Area').count().sort_values(['Y2017'], ascending=True)
# Out:
#                              Y2017
# Area
# Ethiopia PDR                    39
# Comoros                         45
# Sudan (former)                  53
# Seychelles                      68
# Djibouti                      1061
# Guinea-Bissau                 1076
# Mauritania                    1108
# Lesotho                       1110
# Gambia                        1116
# Sao Tome and Principe         1122
# Liberia                       1135
# Sierra Leone                  1191
# Cabo Verde                    1193
# Gabon                         1206
# Togo                          1234
# Mali                          1243
# Eswatini                      1251
# Benin                         1253
# Central African Republic      1262
# Namibia                       1269
# Sudan                         1279
# Algeria                       1279
# Chad                          1281
# Tunisia                       1314
# Ghana                         1333
# ...

# %% [markdown]
# #### Question 2: What is the total number and percentage of missing data in 2014 to 3 decimal places?

# %%
food_df['Y2014'].isnull().sum()
# Out:
# 1589

# %%
food_df.shape[0]
# Out:
# 60943

# %%
percentage = ((food_df['Y2014'].isnull().sum())/food_df.shape[0])*100
percentage
# Out:
# 2.6073544131401474

# %% [markdown]
# #### Question 4: What is the total number and percentage of missing data in 2014 to 3 decimal places?

# %%
food_df['Area'].nunique()
# Out:
# 49

# %% [markdown]
# #### Question 5: y = [(2, 4), (7, 8), (1, 5, 9)]
#
# How would you assign element 8 from the list to a variable x?

# %%
y = [(2, 4), (7, 8), (1, 5, 9)]

x = y[1][1]
x
# Out:
# 8

# %%
y = [(2, 4), (7, 8), (1, 5, 9)]

x = y[1][-1]
x
# Out:
# 8

# %% [markdown]
# #### Question 6: What is the total sum of Wine produced in 2015 and 2018 respectively?

# %%
wine = food_df[['Item','Y2015','Y2018']]
wine
# Out:
#                 Item     Y2015     Y2018
# 0         Population  39728.00  42228.00
# 1         Population      0.00      0.00
# 2        Grand Total   3379.00   3322.00
# 3        Grand Total     94.35     91.83
# 4        Grand Total     79.36     77.28
# ...              ...       ...       ...
# 60938  Miscellaneous     46.00     16.00
# 60939  Miscellaneous      3.33      1.08
# 60940  Miscellaneous      4.00      1.00
# 60941  Miscellaneous      0.11      0.04
# 60942  Miscellaneous      0.05      0.01
#
# [60943 rows x 3 columns]

# %%
wine.groupby('Item').sum()
# Out:
#                          Y2015      Y2018
# Item
# Alcohol, Non-Food      2180.00    2293.00
# Alcoholic Beverages   98783.72   97847.27
# Animal Products       11811.73   11578.61
# Animal fats          200675.72  269648.27
# Apples and products   10559.15    9640.51
# ...                        ...        ...
# Vegetables, Other    158104.08  163987.21
# Vegetal Products     107064.17  107775.39
# Wheat and products   234710.51  242645.19
# Wine                   4251.81    4039.32
# Yams                 203151.78  221272.09
#
# [119 rows x 2 columns]

# %% [markdown]
# #### Question 7: Perform a groupby operation on ‘Element’. What year has the highest sum of Stock Variation?

# %%
stock_variation = food_df.iloc[:,[5,7,8,9,10,11]]
stock_variation
# Out:
#                                       Element     Y2014     Y2015     Y2016  \
# 0               Total Population - Both sexes  38924.00  39728.00  40551.00
# 1                    Domestic supply quantity      0.00      0.00      0.00
# 2               Food supply (kcal/capita/day)   3377.00   3379.00   3372.00
# 3      Protein supply quantity (g/capita/day)     94.90     94.35     94.72
# 4          Fat supply quantity (g/capita/day)     80.06     79.36     77.40
# ...                                       ...       ...       ...       ...
# 60938                                    Food     42.00     46.00     33.00
# 60939     Food supply quantity (kg/capita/yr)      3.06      3.33      2.35
# 60940           Food supply (kcal/capita/day)      3.00      4.00      3.00
# 60941  Protein supply quantity (g/capita/day)      0.10      0.11      0.08
# 60942      Fat supply quantity (g/capita/day)      0.04      0.05      0.03
#
#           Y2017     Y2018
# 0      41389.00  42228.00
# ...

# %%
stock_variation.groupby('Element').sum()
# Out:
#                                              Y2014       Y2015       Y2016  \
# Element
# Domestic supply quantity                1996716.35  2021493.55  2044842.70
# Export Quantity                          150020.64   157614.47   151920.46
# Fat supply quantity (g/capita/day)        10225.56    10235.74    10102.77
# Feed                                     216927.89   225050.22   228958.65
# Food                                    1212332.49  1232361.10  1247022.17
# Food supply (kcal/capita/day)            454257.00   453383.00   451810.00
# Food supply quantity (kg/capita/yr)       49650.63    49345.13    48985.28
# Import Quantity                          274144.48   267018.46   286582.78
# Losses                                   153223.00   155439.00   157787.00
# Other uses (non-food)                     78718.13    66254.41    69563.68
# Processing                               282923.00   287929.00   280631.00
# ...

# %% [markdown]
# #### Question 8: Perform a groupby operation on ‘Element’. What is the total number of the sum of Processing in 2017?

# %%
stock_variation.groupby('Element').sum()
# Out:
#                                              Y2014       Y2015       Y2016  \
# Element
# Domestic supply quantity                1996716.35  2021493.55  2044842.70
# Export Quantity                          150020.64   157614.47   151920.46
# Fat supply quantity (g/capita/day)        10225.56    10235.74    10102.77
# Feed                                     216927.89   225050.22   228958.65
# Food                                    1212332.49  1232361.10  1247022.17
# Food supply (kcal/capita/day)            454257.00   453383.00   451810.00
# Food supply quantity (kg/capita/yr)       49650.63    49345.13    48985.28
# Import Quantity                          274144.48   267018.46   286582.78
# Losses                                   153223.00   155439.00   157787.00
# Other uses (non-food)                     78718.13    66254.41    69563.68
# Processing                               282923.00   287929.00   280631.00
# ...

# %% [markdown]
# #### Question 9

# %%
lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]

col = ['Age','Nationality','Overall']

pd1 = pd.DataFrame(lst,columns=col,index=[i for i in range(1,4)])
pd1
# Out:
#    Age Nationality  Overall
# 1   35    Portugal       94
# 2   33   Argentina       93
# 3   30      Brazil       92

# %%
lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]

col = ['Age','Nationality','Overall']

pd2 = pd.DataFrame(lst,columns=col,index=[1,2,3])
pd2
# Out:
#    Age Nationality  Overall
# 1   35    Portugal       94
# 2   33   Argentina       93
# 3   30      Brazil       92

# %% [markdown]
# #### Question 10

# %%
my_tuppy = (1,2,5,8)

my_tuppy[2] = 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15784/3917941094.py in <module>
#       1 my_tuppy = (1,2,5,8)
#       2
# ----> 3 my_tuppy[2] = 6
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# #### Question 13

# %%
food_df.shape
# Out:
# (60943, 12)

# %% [markdown]
# #### Question 14

# %%
arr = np.array([[94, 89, 63],

             [93, 92, 48],

             [92, 94, 56]])

# %%
arr[:2,1:]
# Out:
# array([[89, 63],
#        [92, 48]])

# %% [markdown]
# #### Question 15: Select columns ‘Y2017’ and ‘Area’, Perform a groupby operation on ‘Area’. Which of these Areas had the highest sum in 2017?

# %%
food_by_area.groupby('Area').sum().sort_values(['Y2017'], ascending=True)
# Out:
#                                   Y2017
# Area
# Sudan (former)                     0.00
# Ethiopia PDR                       0.00
# Comoros                           59.84
# Seychelles                       442.34
# Sao Tome and Principe          12662.63
# Cabo Verde                     14650.74
# Guinea-Bissau                  19102.77
# Lesotho                        21267.96
# Botswana                       22101.30
# Djibouti                       22729.91
# Gambia                         23154.18
# Gabon                          27979.64
# Liberia                        29342.20
# Namibia                        29874.89
# Central African Republic       29937.00
# Congo                          41181.68
# Togo                           49841.88
# Mauritius                      51114.83
# Eswatini                       54343.33
# Sierra Leone                   55311.33
# Chad                           71594.68
# Rwanda                         73663.69
# ...

# %% [markdown]
# #### Question 17: What is the mean and standard deviation across the whole dataset for the year 2017 to 2 decimal places?

# %%
food_df['Y2017'].mean()
# Out:
# 140.917764860268

# %%
food_df['Y2017'].std()
# Out:
# 1671.8623590572788

# %% [markdown]
# #### Question 19

# %%
S = [['him', 'sell'], [90, 28, 43]]

S[0][1][1]
# Out:
# 'e'
